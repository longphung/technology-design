# %%
import pandas as pd

# List of questions related to student life at Swinburne University
in_scope_questions = [
    "What are the advantages of studying abroad?",
    "How can I improve my study habits?",
    "What are the steps to apply for financial aid?",
    "Can you recommend effective note-taking strategies?",
    "What are the requirements to graduate with honors?",
    "How can I find research opportunities on campus?",
    "What are the benefits of joining a student organization?",
    "Can you provide tips for time management during exams?",
    "What resources are available for career counseling?",
    "How can I find internships related to my field of study?",
    "What are the steps to declare a major or minor?",
    "Can you recommend books for personal development?",
    "What are the benefits of participating in study groups?",
    "How can I improve my presentation skills for class projects?",
    "What are the options for studying abroad in my major?",
    "Can you provide guidance on choosing a research topic?",
    "What are the steps to secure housing for the upcoming semester?",
    "How can I get involved in undergraduate research?",
    "What are the benefits of attending academic conferences?",
    "Can you recommend time management apps for students?",
    "What are the options for online courses or distance learning?",
    "How can I build a professional network while in university?",
    "What are the steps to apply for scholarships?",
    "Can you provide guidance on writing a research paper?",
    "What are the benefits of participating in community service?",
    "How can I prepare for graduate school admissions?",
    "What are the options for studying abroad on a budget?",
    "Can you recommend strategies for reducing test anxiety?",
    "What are the steps to secure an on-campus job?",
    "How can I develop effective study schedules?",
    "What are the benefits of undergraduate research?",
    "Can you provide tips for balancing academics and extracurricular activities?",
    "What are the options for studying abroad during summer break?",
    "How can I improve my critical thinking skills?",
    "What are the steps to create a study plan?",
    "Can you recommend resources for academic writing?",
    "What are the benefits of participating in study abroad programs?",
    "How can I manage my workload effectively?",
    "What are the options for online tutoring services?",
    "Can you provide guidance on choosing electives?",
    "What are the benefits of undergraduate research grants?",
    "How can I enhance my research skills?",
    "What are the steps to apply for research funding?",
    "Can you recommend strategies for improving concentration during lectures?",
    "What are the options for study abroad scholarships?",
    "How can I develop effective note-taking techniques?",
    "What are the benefits of attending faculty office hours?",
    "How can I handle academic stress effectively?"
]


# Generate out-of-scope questions by random sampling from a larger pool
out_of_scope_questions = [
    "What are the best hiking trails in Patagonia?",
    "How can I become a professional dancer?",
    "What are the symptoms of a sinus infection?",
    "Can you recommend a good skincare routine for acne-prone skin?",
    "What are the top tourist attractions in Sydney?",
    "What are the symptoms of seasonal allergies?",
    "Can you recommend a good book for fantasy lovers?",
    "What are the requirements to become a lawyer?",
    "How do I repair a broken bicycle chain?",
    "What are the latest fashion trends for winter?",
    "Can you provide information about the history of Ancient Rome?",
    "What are the different types of database management systems?",
    "How can I unclog a kitchen sink?",
    "What are the symptoms of a migraine?",
    "Can you recommend a good TV series to binge-watch?",
    "What are the popular tourist attractions in Barcelona?",
    "What are the benefits of practicing yoga?",
    "Can you provide information about the life cycle of a frog?",
    "What are the steps to make homemade ice cream?",
    "How can I train my cat to use the litter box?",
    "What are the best practices for social media marketing?",
    "Can you recommend a good workout routine for building muscle?",
    "What are the top vacation spots in the Maldives?",
    "How do I install a ceiling fan?",
    "What are the health risks of excessive alcohol consumption?",
    "Can you provide information about the planets in the Milky Way?",
    "What are the steps to write a novel?",
    "What are the benefits of eating a vegetarian diet?",
    "Can you recommend a good hiking trail in the Grand Canyon?",
    "What are the rules of tennis?",
    "How do I sew a button on a shirt?",
    "What are the symptoms of a common cold?",
    "Can you provide information about the life of Marie Curie?",
    "What are the different genres of film?",
    "How can I fix a leaky faucet?",
    "What are the latest fashion trends for men's clothing?",
    "Can you recommend a good podcast for learning a new language?",
    "What are the popular tourist attractions in Rome?",
    "How do I create a budget for personal finances?",
    "What are the benefits of regular cardiovascular exercise?",
    "Can you provide information about the history of ancient China?",
    "What are the steps to create a mobile app?",
    "How can I improve my photography composition?",
    "What are the health benefits of drinking herbal tea?",
    "Can you recommend a good recipe for lasagna?",
    "What are the rules of golf?",
    "How do I fix a flat tire on a bicycle?",
    "Can you provide information about the life of Vincent van Gogh?",
    "What are the different types of musical genres?",
    "How can I make a homemade face scrub?",
    "What are the top tourist attractions in Paris?",
    "How do I set up a home theater system?",
    "What are the health benefits of practicing meditation?",
    "Can you recommend a good documentary about wildlife?",
    "What are the popular vacation destinations in Greece?",
    "How do I create a professional resume?",
    "What are the benefits of drinking enough water daily?",
    "Can you provide information about the history of ancient Rome's gladiators",
]



# Create the dataframe
test_data = pd.DataFrame({
    'Question': in_scope_questions + out_of_scope_questions,
    'Label': [0] * len(in_scope_questions) + [1] * len(out_of_scope_questions)
})

# Save the dataframe to a CSV file
test_data.to_csv('scope_training_datasets/testdata_student_life5.csv', index=False)
